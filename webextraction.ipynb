# %%
import requests
import re
import pandas as pd

# %%
from bs4 import BeautifulSoup

# %%
import bs4

# %%
from bs4 import BeautifulSoup

# %%
from textblob import TextBlob, Word, Blobber
from textblob.classifiers import NaiveBayesClassifier
from textblob.taggers import NLTKTagger

# %%
wk= TextBlob("He is not beautiful")

# %%
wk.sentiment.polarity
# Out:
# -0.425

# %%
import bs4

# %%
from bs4 import BeautifulSoup

# %%
link='http://www.myneta.info/ls2014/index.php?action=show_winners&sort=default'
res= requests.get(link)

# %%
type(res)
# Out:
# requests.models.Response

# %%
res.text
# Out:
# '\t\t\t<html>\n\t\t\t\t<head>\n\t\t\t\t   <title>List of Winners:Loksabha 2014 Election</title>\n\t\t\t\t   <meta name="description" content="It provides criminal and financial background information on candidates, MPs and MLAs contesting in elections.It also has information on income and expenditure of political parties.">\n                                <META HTTP-EQUIV="Content-Type" CONTENT="text/html; charset=UTF-8">\n    \t\t\t\t<meta http-equiv="x-ua-compatible" content="ie=edge"/>\n    \t\t\t\t<meta name="viewport" content="width=device-width, initial-scale=1, minimum-scale=1, maximum-scale=1"/>\n    \t\t\t\t<meta name="author" content="ADR"/>\n                                <link rel="shortcut icon" type="image/x-icon" href="../favicon.ico">\n    \t\t\t\t<link rel="stylesheet" href="/lib/css/text.css"/>\n    \t\t\t\t<link rel="stylesheet" href="/lib/css/main.css"/>\n                                <script type="text/javascript" src="//platform-api.sharethis.com/js/sharethi
# ...

# %%
soup = bs4.BeautifulSoup(res.text, 'lxml')

# %%
title=soup.select('title')

# %%
title
# Out:
# [<title>List of Winners:Loksabha 2014 Election</title>]

# %%
title[0].getText()
# Out:
# 'List of Winners:Loksabha 2014 Election'

# %%
for i in soup.select('.alt'):
    print(i.text)
# Out:
# 2
# Dr. Ramshankar KatheriaAGRA
# BJP
#  21  Doctorate
# Rs 1,46,34,885 ~ 1 Crore+
# Rs 40,35,000 ~ 40 Lacs+
#
#
# 4
# Dr. Solanki Kiritbhai PremjibhaiAHMEDABAD WEST
# BJP
# 0 Post Graduate
# Rs 3,40,85,266 ~ 3 Crore+
# Rs 2,08,007 ~ 2 Lacs+
#
#
# 6
# Sanwar Lal JatAJMER
# BJP
# 0 Doctorate
# Rs 1,80,64,656 ~ 1 Crore+
# Rs 0 ~
#
#
# 8
# Dhotre Sanjay ShyamraoAKOLA
# BJP
#  3  Graduate Professional
# Rs 4,85,01,735 ~ 4 Crore+
# Rs 69,28,458 ~ 69 Lacs+
#
#
# 10
# P.K.BijuALATHUR
# CPI(M)
# 0 Post Graduate
# Rs 32,31,047 ~ 32 Lacs+
# Rs 3,41,749 ~ 3 Lacs+
#
#
# 12
# Dasrath TirkeyALIPURDUARS
# AITC
# 0 Graduate
# Rs 35,50,353 ~ 35 Lacs+
# Rs 2,93,909 ~ 2 Lacs+
#
#
# 14
# Ajay TamtaALMORA
# BJP
# 0 12th Pass
# Rs 63,66,653 ~ 63 Lacs+
# Rs 27,57,846 ~ 27 Lacs+
#
#
# 16
# Pandula Ravindra BabuAMALAPURAM
# TDP
# 0 Graduate Professional
# Rs 2,71,31,000 ~ 2 Crore+
# Rs 30,00,000 ~ 30 Lacs+
#
#
# 18
# HariomAMBEDKAR NAGAR
# BJP
# 0 Post Graduate
# Rs 1,53,18,114 ~ 1 Crore+
# Rs 0 ~
#
#
# 20
# ...

# %%
try: 
	from googlesearch import search 
except ImportError: 
	print("No module named 'google' found") 

# to search 
pol= "politics"
name=input()
query = name + " " + pol
for j in search(query, tld="co.in", num=10, stop=5, pause=2): 
	print(j)
# Out:
# mimi
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-18-8c961e6a4a97> in <module>()
#       8 name=input()
#       9 query = name + " " + pol
# ---> 10 for j in search(query, tld="co.in", num=10, stop=5, pause=2):
#      11         print(j)
#
# c:\users\abdul\appdata\local\programs\python\python37-32\lib\site-packages\googlesearch\__init__.py in search(query, tld, lang, tbs, safe, num, start, stop, domains, pause, only_standard, extra_params, tpe, user_agent)
#     286
#     287         # Request the Google Search results page.
# --> 288         html = get_page(url, user_agent)
#     289
#     290         # Parse the response and process every anchored URL.
#
# c:\users\abdul\appdata\local\programs\python\python37-32\lib\site-packages\googlesearch\__init__.py in get_page(url, user_agent)
#     152     request.add_header('User-Agent', user_agent)
# ...
